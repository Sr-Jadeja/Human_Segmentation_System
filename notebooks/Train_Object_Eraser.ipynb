# %%
# !git clone https://github.com/Sr-Jadeja/Object_Eraser.git
# %cd Object_Eraser
# Out:
# Cloning into 'Object_Eraser'...
# remote: Enumerating objects: 35, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 35 (delta 9), reused 27 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (35/35), 14.00 KiB | 1.75 MiB/s, done.
# Resolving deltas: 100% (9/9), done.
# /content/Object_Eraser

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-a937c2ca-df3f-432b-869a-b3ec835e1cfe" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a937c2ca-df3f-432b-869a-b3ec835e1cfe">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d tapakah68/supervisely-filtered-segmentation-person-dataset
# !unzip supervisely-filtered-segmentation-person-dataset.zip -d data_raw
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: data_raw/supervisely_person_clean_2667_img/supervisely_person_clean_2667_img/images/ds2_person-human-female-girl.png
#   inflating: data_raw/supervisely_person_clean_2667_img/supervisely_person_clean_2667_img/images/ds2_person-woman-coffee-cup.png
#   inflating: data_raw/supervisely_person_clean_2667_img/supervisely_person_clean_2667_img/images/ds2_person-woman-eyes-face.png
#   inflating: data_raw/supervisely_person_clean_2667_img/supervisely_person_clean_2667_img/images/ds2_person-woman-hotel-laptop.png
#   inflating: data_raw/supervisely_person_clean_2667_img/supervisely_person_clean_2667_img/images/ds2_pexels-photo-105472.png
#   inflating: data_raw/supervisely_person_clean_2667_img/supervisely_person_clean_2667_img/images/ds2_pexels-photo-123318.png
#   inflating: data_raw/supervisely_person_clean_2667_img/supervisely_person_clean_2667_img/images/ds2_pexels-photo-125522.png
# ...

# %%
# !kaggle datasets download -d tapakah68/supervisely-filtered-segmentation-person-dataset
# !unzip supervisely-filtered-segmentation-person-dataset.zip -d data_raw
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: data_raw/supervisely_person_clean_2667_img/supervisely_person_clean_2667_img/images/ds2_person-human-female-girl.png
#   inflating: data_raw/supervisely_person_clean_2667_img/supervisely_person_clean_2667_img/images/ds2_person-woman-coffee-cup.png
#   inflating: data_raw/supervisely_person_clean_2667_img/supervisely_person_clean_2667_img/images/ds2_person-woman-eyes-face.png
#   inflating: data_raw/supervisely_person_clean_2667_img/supervisely_person_clean_2667_img/images/ds2_person-woman-hotel-laptop.png
#   inflating: data_raw/supervisely_person_clean_2667_img/supervisely_person_clean_2667_img/images/ds2_pexels-photo-105472.png
#   inflating: data_raw/supervisely_person_clean_2667_img/supervisely_person_clean_2667_img/images/ds2_pexels-photo-123318.png
#   inflating: data_raw/supervisely_person_clean_2667_img/supervisely_person_clean_2667_img/images/ds2_pexels-photo-125522.png
# ...

# %%
# !ls data_raw
# Out:
# df.csv	supervisely_person_clean_2667_img

# %%
# !find data_raw -maxdepth 3 -type d
# Out:
# data_raw
# data_raw/supervisely_person_clean_2667_img
# data_raw/supervisely_person_clean_2667_img/supervisely_person_clean_2667_img
# data_raw/supervisely_person_clean_2667_img/supervisely_person_clean_2667_img/masks
# data_raw/supervisely_person_clean_2667_img/supervisely_person_clean_2667_img/images
# data_raw/supervisely_person_clean_2667_img/supervisely_person_clean_2667_img/collage

# %%
# !mkdir -p data/images data/masks

# %%
# !cp data_raw/supervisely_person_clean_2667_img/supervisely_person_clean_2667_img/images/* data/images/
# !cp data_raw/supervisely_person_clean_2667_img/supervisely_person_clean_2667_img/masks/* data/masks/

# %%
# !ls data/images | wc -l
# !ls data/masks | wc -l
# Out:
# 2667
# 2667

# %%
# !python -m src.train
# Out:
# 2026-02-10 16:45:55.923943: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1770741956.128956    6550 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1770741956.186786    6550 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1770741956.584884    6550 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !ls weights
# Out:
# model.h5
